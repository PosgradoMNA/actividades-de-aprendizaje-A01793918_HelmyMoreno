# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-de-aprendizaje-Handrum/blob/main/Avance04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Lists and Tuples")
# Out:
# Lists and Tuples

# %% [markdown]
# Estos se denominan tipos de datos compuestos y son uno de los tipos clave de estructuras de datos en Python.
#
# **Tuplas**
# Las tuplas son una secuencia ordenada. Aquí hay una tupla "Calificaciones":
#
#       **Ratings**=(10,9, 6, 5, 10, 8,9,6,2)
#
# Las **tuplas** se expresan como **elementos separados por comas** entre paréntesis. Estos son valores dentro de los paréntesis.
# En Python, hay diferentes tipos:
# - Cadenas(str), enteros(int), flotantes(float)
# Todos pueden estar contenidos en una tupla, pero el tipo de la variable es tupla.
#
#       **tupla1**=(“disco”, 10, 1.2)
#
#       type(tupla1)=tuple
#
#
# Se puede acceder a cada elemento de una tupla a través de un índice.
# La siguiente tabla representa la relación entre el índice y los elementos en el
# Tupla:
#
# 0    “disco”
#
# 1	    10
#
# 2     1.2
#
# Se puede acceder al primer elemento por el nombre de la tupla seguido de un corchete
# con el número de índice, en este caso, cero:
#
#     tuple1[0]: “disco”
#
# Podemos acceder al segundo elemento de la siguiente manera:
#
#     tuple1[1]: 10
#
# También podemos acceder al último elemento:
#
#         tuple1[2]: 1.2
#
# En Python, podemos usar índice negativo. La relación es la siguiente. Los valores correspondientes se muestran aquí:
#
#         -3	“disco”
#
#         -2	10
#
#         -1	1.2
#
# Podemos concatenar o combinar tuplas añadiéndolas. El resultado es el siguiente con el siguiente índice:
#
#         tupla1 = (“disco”, 10, 1.2)
#
#         tupla2 =  tupla1+(“hard rock”, 10)
#
#         tupla2 = (“disco”,  10,  1.2, “hard rock”, 10)
#
#                     0        1      2        3  	4
#
# **Slicing**
#
# Si quisiéramos múltiples elementos de una tupla, también podríamos dividir tuplas. Por ejemplo, si queremos los primeros tres elementos, usamos el siguiente comando:
#
#       Tupla2[0:3]:[“disco”,  10,  1.2]
#
# El último índice es 1 más grande que el índice que desea.
#
# De manera similar, si queremos los dos últimos elementos, usamos el siguiente comando:
#
#       Tupla2[0:3]:[“disco”,  10,  1.2]
#
#       Tupla2[3:5] =>[“hard rock”,  10]
#
# Observe cómo el último índice es 1 más grande que la longitud de la tupla.
# Podemos usar el comando "len" para obtener la longitud de una tupla.
# Como hay 5 elementos, el resultado es cinco.
#
#       len = ((“disco”,  10,  1.2, “hard rock”, 10)) = 5
#
# Las tuplas son inmutables, lo que significa que no podemos cambiarlas. Para ver por qué esto es importante, veamos qué sucede cuando configuramos la variable Calificaciones 1 (Raitings) a las calificaciones:
#
#       Ratings=(10,9, 6, 5, 10, 8,9,6,2)
#
#       Ratings1=Raitings
#
# Cada variable **no contiene una tupla**, pero hace referencia al mismo objeto de **tupla inmutable**.
#
#
#
# **Inmutables**
#
# Debido a que las tuplas son inmutables, no podemos. Por lo tanto, Ratings 1 no se verá afectado por un cambio en Rating porque **la tupla es inmutable**, es decir, no podemos cambiarlo.
# Podemos asignar una tupla diferente a la variable Calificaciones(Ratings):
#
#       Ratings=(2,10,1)
#
# La variable Calificaciones ahora hace referencia a **otra tupla**. Como consecuencia de la inmutabilidad, si queremos manipular una tupla, debemos crear una nueva tupla en su lugar. Por ejemplo, si queremos ordenar una tupla, usamos la **función sorted**:
#
# La entrada es la tupla original:
#
#       RatingsSorted = sorted(Ratings)
#
# La salida es una nueva tupla ordenada.
#
#       = (10, 9,  6,  5,  10,  8, 9, 6, 2)
#
#
#
# **Nesting**
#
# **Una tupla puede contener otras tuplas** así como otros tipos de datos complejos; esto se llama anidamiento:
#
#       NT = (1,  2, (“pop”, “rock”), (3,4), (“disco”, (1,2))
#             0, 1	       2	          3		    4
#       NT[2] = (“pop”, “rock”) [1] = “rock”
#               0 	    1
# Podemos acceder a estos elementos utilizando los métodos de **indexación estándar**. Si seleccionamos un índice con una tupla, se aplica la misma convención de índice. Como tal, podemos acceder a los valores de la tupla.
#
# Por ejemplo, podríamos acceder al segundo elemento.
#
# Podemos aplicar esta **indexación directamente** a la variable de tupla NT.
#
#       NT[2] [1]  = “rock”
#
# Es útil visualizar esto como un árbol. Podemos visualizar este anidamiento como un árbol.
# La tupla tiene los siguientes índices. Si consideramos índices con otras tuplas, vemos que la tupla en el índice 2 contiene una tupla con dos elementos. Podemos acceder a esos dos índices. La misma convención se aplica al índice 3. También podemos acceder a los elementos de esas tuplas. Podemos continuar el proceso. Incluso podemos acceder a niveles más profundos del árbol agregando otro corchete. Podemos acceder a diferentes **caracteres de la cadena** o a varios elementos de la segunda tupla contenida en la primera.
#
#
# **Las listas**
#
# También son una estructura de datos popular en Python. Las listas también son una secuencia ordenada.
#
# Aquí hay una lista **L**.
#
#       L = [“Michael Jackson”, 10.1, 1982]
#
# Una lista se representa con corchetes. En muchos aspectos, las listas son como tuplas, una diferencia clave es que son mutables. Las listas pueden contener cadenas, flotantes, enteros.
#
# Podemos anidar otras listas. También anidamos tuplas y otras estructuras de datos; se aplican las mismas convenciones de indexación para el anidamiento. Al igual que las tuplas, se puede acceder a cada elemento de una lista a través de un índice.
# La siguiente tabla representa la relación entre el índice y los elementos en el lista. En Python, podemos usar un índice negativo. La relación es la siguiente.
#
#       -3 	L [0] 	“Michael Jackson”
#
#       -2	L [1] 	10.1
#
#       -1	L [2]  	1982
#
# Se puede acceder **al primer elemento** por el nombre de la lista seguido de un corchete con el número de índice, en este caso cero. Podemos acceder al segundo elemento de la siguiente manera. También podemos acceder al último elemento.
#
# **Slicing**
#
# También podemos realizar cortes en listas.
#
#       L [3:5]: [“MJ”, 1]
#
# Por ejemplo, si queremos los dos últimos elementos de esta lista, usamos el siguiente comando.
# Observe cómo el último índice es 1 más grande que la longitud de la lista.
#
# Las convenciones de índice para listas y tuplas son idénticas. Consulte los laboratorios para obtener más ejemplos.
#
# Podemos concatenar o combinar listas agregándolas. El resultado es el siguiente:
#
#       L = [“Michael Jackson”, 10.1, 1982]
#       L1 = L+[“pop”, 10]
#       L1 = [“Michael Jackson”, 10.1, 1982, “pop”, 10]
#
# La nueva lista tiene los siguientes índices:
#
#       L1 = [“Michael Jackson”, 10.1, 1982, “pop”, 10]
#                    0            1     2      3     4
#
# **Método Extend**
#
# Las listas son mutables, por lo tanto, podemos cambiarlas. Por ejemplo, aplicamos el método extends agregando un "punto" seguido del nombre del método, luego paréntesis:
#
#       L = [“Michael Jackson”, 10.1, 1982]
#       L.extend([“pop”, 10])
#       L1 = [“Michael Jackson”, 10.1, 1982, “pop”, 10]
#                   0             1     2      3     4
#
# El argumento dentro del paréntesis es una nueva lista que vamos a concatenar al
# lista original. En este caso, en lugar de crear una nueva lista, L1, se modifica la lista original L agregando dos nuevos elementos:
#
# Para obtener más información sobre los métodos, consulte nuestro video sobre objetos y clases.
#
# **Método append**
#
# Otro método similar es append. Si aplicamos append en lugar de extended, agregamos un elemento a la lista.
#
#       L = [“Michael Jackson”, 10.1, 1982]
#       L.append([“pop”, 10])
#       L1 = [“Michael Jackson”, 10.1, 1982, [“pop”, 10]]
#                   0              1     2        3
#
# Si miramos el índice, sólo hay un elemento más. El índice 3 contiene la lista que adjuntamos.
#
# Cada vez que aplicamos un método, la lista cambia. Si aplicamos extend,agregamos dos nuevos elementos a la lista. Se modifica la lista L añadiendo dos nuevos elementos.
#
# Si agregamos la cadena "A", cambiamos aún más la lista agregando la cadena "A".
# L.append(“A”)
#
#       L1 = [“Michael Jackson”, 10.1, 1982, [“pop”, 10], “A”]
#
# Como las listas son mutables, podemos cambiarlas. Por ejemplo, podemos cambiar el primer elemento de la siguiente manera:
#
# La lista pasa a ser ahora:
#
#       “Hard rock”, 10, 1.2.
#       A=[“disco”, 10, 1.2]
#       A[0]=”hard rock”
#       A= [“Hard rock”, 10, 1.2]
# Podemos borrar un elemento de una lista usando el comando **"del"**; simplemente indicamos la lista elemento que nos gustaría eliminar como argumento. Por ejemplo, si quisiéramos eliminar el primer elemento, el resultado sería:
#
#       10,1.2.
#       del(A[0])
#       A= [10, 1.2]
# Podemos eliminar el segundo elemento. Esta operación elimina el segundo elemento de la lista:
#       del(A[1])
#       A= [“Hard rock”, 1.2]
#
# **Método Split**
#
# Podemos convertir una cadena en una lista usando split. Por ejemplo, el método split convierte cada grupo de caracteres separados por un espacio en un elemento de una lista.
#
#       “Hard rock”.split()
#       [“Hard”, “rock”]
#
# Podemos usar la función dividir para separar cadenas en un carácter específico, conocido como un delimitador. Simplemente pasamos el delimitador en el que nos gustaría dividir como argumento, en este caso una coma. El resultado es una lista, cada elemento corresponde a un conjunto de caracteres que han sido separados por una coma:
#
#       “A,B,C,D”.split(“,”)
#       [“A”, “B”, ”C”, “D”]
#
# **Método aliasing**
#
# Cuando establecemos una variable, B igual a A, tanto A como B hacen referencia a la misma lista.
# Múltiples nombres que se refieren al mismo objeto se conocen como aliasing. Sabemos por la última diapositiva que el primer elemento en B está configurado como Hard rock.
#
# Si cambiamos el primer elemento en "A" a "banana" obtenemos un efecto secundario; el valor de B cambiará como consecuencia. "A" y "B" están haciendo referencia a la misma lista, por lo tanto, si cambiamos "A", la lista "B" también cambios.
#
# Si verificamos el primer elemento de B después de cambiar la lista "A", obtenemos banana en lugar de hard rock.
#
#
# **Método clone**
#
# Puede clonar la lista "A" usando la siguiente sintaxis:
#
#       A= [“Hard rock”, 10, 1.2]
#       B= [“Hard rock”, 10, 1.2]
#       B=A[:]
#
# La variable **"A"** hace referencia a una lista.
# La variable **"B"** hace referencia a una nueva copia o clon de la lista original.
# Ahora, si cambia **"A", "B"** no cambiará.
# Podemos obtener más información sobre listas, tuplas y muchos otros objetos en Python usando la ayuda dominio.
#
#       help= (A)
#
# Simplemente pase la lista, la tupla o cualquier otro objeto de Python.
# Consulte los laboratorios para conocer más cosas que puede hacer con las listas.
#
# **Sets o Conjuntos**
#
# Los conjuntos; también son un **tipo de colección**. Los conjuntos son un tipo de colección. Esto significa que, al igual que las listas y las tuplas, puede ingresar diferentes tipos de información o código. A diferencia de las listas y las tuplas, están desordenadas. Esto significa que los conjuntos no registran la posición del elemento. Los conjuntos solo tienen elementos únicos.
#
# Esto significa que solo hay uno de un elemento particular en un conjunto. Para definir un conjunto, se utilizan corchetes. Se colocan los elementos de un conjunto dentro del corchete. Observa que hay elementos duplicados.
#
#       Set1 = {“pop”, “rock”, “soul”, “hard rock”, “rock”, “R&B”, “rock”, “disco”}
#
# Cuando se crea el conjunto real, los elementos duplicados no estarán presentes:
#
#       Set1 = {“rock”, “R&B”, “hard rock”, “pop”,  “disco”, “soul”}
#
# Puede convertir una lista en un conjunto utilizando la función conjunto; esto se llama conversión de tipos. Simplemente use la lista como entrada para el conjunto de funciones:
#
#
#       LIST - set() resultado - set
# El resultado será una lista convertida en un conjunto(set). Repasemos un ejemplo:
#
# Empezamos con una lista. Introducimos la lista en el conjunto de funciones:
#
#       album_list = [“Michael Jackson”, “Thriller”, “Thriller”, 1982]
#       album_set = set(album list)
#
# La función set devuelve un conjunto. Observe cómo no hay elementos duplicados:}}
#
#       álbum_set = [“Michael Jackson”, “Thriller”, 1982]
#
#
# **Operations**
#
# Repasemos las operaciones de conjuntos; estos se pueden utilizar para cambiar el conjunto.
# Considere el conjunto "A". Representemos este conjunto con un círculo:
#
#       A= [“Thriller”, “Back and Black”, “AC/DC”]
#
# Si está familiarizado con los conjuntos, esto puede ser parte de un diagrama de Venn. Un diagrama de Venn es una herramienta que utiliza formas generalmente para representar conjuntos:
#
# Podemos agregar un elemento a un conjunto usando el método de agregar.
#
#       A= {“Thriller”, “Back and Black”, “AC/DC”}
#
# Simplemente ponemos el nombre del conjunto seguido de un punto, luego el método de agregar.
# El argumento es el nuevo elemento del conjunto que nos gustaría agregar, en este caso, "NSYNC".
#
#       A.add(“NSYCN”)
#       A: {“AC/DC”, “Back and Black”, “NSYCN”, “Thriller”}
#
# El conjunto "A" ahora tiene "NSYNC" como elemento. Si agregamos el mismo elemento dos veces, nada sucede ya que no puede haber duplicados en un conjunto.
#
# **Método remove**
#
# Digamos que nos gustaría eliminar NSYNC del conjunto A. También podemos eliminar un elemento de un conjunto utilizando el método de eliminación(remove). Simplemente ponemos el nombre del conjunto seguido de un punto y luego el método de eliminación. El argumento es el elemento del conjunto que nos gustaría eliminar, en este caso, "NSYNC".
#
#         A.remove(“NSYCN”)
#         A: {“AC/DC”, “Back and Black”, “Thriller”}
#
# Después de aplicar el método de eliminación al conjunto, el conjunto "A" no contiene el elemento "NSYNC". Puede utilizar este método para cualquier elemento del conjunto.
#
# **Comando “in”**
#
# Podemos verificar si un elemento está en el conjunto usando el comando "in" de la siguiente manera. El comando comprueba si el elemento, en este caso, "AC/DC" está en el conjunto.
#
# Si el elemento está en el conjunto, devuelve verdadero.
#
#         A: {“AC/DC”, “Back and Black”, “Thriller”}
#
#         “AC/DC” in A
#         True
# Si buscamos un ítem que no está en el conjunto, en este caso el ítem “Quién”:
#
#         “Quién” in A
#         False
#
# Como el artículo no está en el conjunto, obtendremos un **falso**.
#
# Estos son tipos de operaciones matemáticas con conjuntos; hay otras operaciones que podemos hacer. Hay muchas operaciones matemáticas útiles que podemos hacer entre conjuntos. Definamos el conjunto "album_set_1", podemos representarlo usando un círculo rojo o un diagrama de Venn. Del mismo modo, podemos definir el conjunto "album_set_2".
#
#       album_set_1 = {“AC/DC”, “Back and Black”, “Thriller”}
#       album_set_2  = {“AC/DC”, “Back and Black”, “The dark side of the moon”}
#
# La **intersección de dos conjuntos** es un nuevo conjunto que contiene elementos que están en ambos conjuntos. Es útil usar diagramas de Venn. Los dos círculos que representan los conjuntos se combinan; la superposición representa el nuevo conjunto.
#
#
# Como la superposición se compone del círculo rojo y el círculo azul, definimos la intersección
# en términos de **"y"**.
#
# En Python, usamos el ampersand (&) para encontrar la unión de dos conjuntos. Si superponemos los valores del conjunto sobre el círculo colocando los elementos comunes en la zona de superposición, vemos la correspondencia. Después de aplicar la operación Intersección, todos los elementos que no están en ambos conjuntos desaparecen.
#
#       album_set_1 = {“AC/DC”, “Back and Black”, “Thriller”}
#       album_set_2  = {“AC/DC”, “Back and Black”, “The dark side of the moon”}
#       album_set_3 = album_set_1& album_set_2
#       album_set_3 = {{“AC/DC”, “Back and Black”}
#
# En Python, simplemente colocamos el ampersand entre los dos conjuntos. Vemos que tanto "AC/DC" como "Back in Black" están en ambos sets. El resultado es un nuevo conjunto de álbumes, conjunto 3, que contiene todos los elementos tanto en album_set_1 como en album
# conjunto 2.
#
# La unión de dos conjuntos es el nuevo conjunto de elementos que contienen todos los elementos de ambos conjuntos. Podemos encontrar la unión de los sets album set_1 y album_set_2 de la siguiente manera:
#
#       album_set_1.union (álbum_set_2)
#       {“AC/DC”, “Back and Black”, “The dark side of the moon”, “Thriller”}
#
# El resultado es un nuevo conjunto que tiene todos los elementos de album_set_1 y album_set_2. Este nuevo conjunto está representado en verde.
#
# Considere el nuevo conjunto de álbumes, "album_set_3"; el set contiene los elementos "AC/DC" y " Back and Black ". Podemos representar esto con un diagrama de Venn, ya que todos los elementos en album_set_3 están en album_set_1.
#
#       album_set_1 = {“AC/DC”, “Back and Black”, “Thriller”}
#       album_set_3 = {“AC/DC”, “Back and Black”}
#
# El círculo que representa album_set_1 encapsula el círculo que representa album_set_3. Podemos verificar si un conjunto es un subconjunto utilizando el método is subset.
#
#       album_set_3.issubset(album_set_1)
#
# Como album_set_3 es un subconjunto de album_set_1, el resultado es verdadero. Hay mucho más que puedes hacer con los conjuntos. Echa un vistazo al laboratorio para ver más ejemplos.
#
# **Diccionarios (Dictionary)**
#
# Los diccionarios son un tipo de colección en Python. Si recuerda, una lista tiene índices enteros. Estas son como direcciones. Una lista también tiene elementos. Un diccionario tiene claves y valores.
#
#
#
# La clave es análoga al índice, son como direcciones pero no tienen por qué ser números enteros. Suelen ser personajes; los valores son similares a los elementos de una lista y contienen información.
#
# Para crear un diccionario, usamos corchetes. Las claves son los primeros elementos; ellos deben
# ser inmutable y único. Cada tecla va seguida de un valor separado por un color. Los valores pueden ser inmutables, mutables y duplicados. Cada par de clave y valor está separado por una coma. Considere el siguiente ejemplo de un diccionario:
#
# El título del álbum es la clave y el valor son los datos de lanzamiento. Podemos usar amarillo para resaltar las teclas y dejar los valores en blanco. Es útil usar la tabla para visualizar un diccionario, donde la primera columna representa las claves y la segunda columna representa los valores.
#
# Podemos añadir algunos ejemplos más al diccionario.
# También podemos asignar el diccionario a una variable. La clave se utiliza para buscar el valor. Usamos corchetes; el argumento es la clave. Esto genera el valor.
#
# Usando la clave de "Back in Black", esto devuelve el valor de 1980.
# La clave "El lado oscuro de la luna", nos da el valor de 1973.
# Utilizando la Clave "El Guardaespaldas", nos da el valor 1992, y así sucesivamente.
#
#       DICT["Back in Black"]:”1980”
#
# Podemos agregar una nueva entrada al diccionario de la siguiente manera:
# Esto agregará el valor 2007 con la nueva clave llamada "Graduación".
#
#       DICT["Graduación"]=”2007”
#
# Podemos eliminar una entrada de la siguiente manera:
#
#       Del(DICT["Thriller"])
#
# Esto elimina la clave "Thriller" y su valor.
#
# Podemos verificar si un elemento está en el diccionario usando el comando in de la siguiente manera. El comando comprueba las claves, si están en el diccionario, devuelven un verdadero. Si intentamos el mismo comando con una tecla que no está en el diccionario, obtenemos un falso. Si probamos con otra llave que no está en el diccionario, obtenemos un falso.
#
#       "The Bodyguard" in DICT
#       True
#
#
#
# Para ver todas las claves en un diccionario, podemos usar las claves de método para obtener las claves. La salida es una lista como objeto con todas las llaves. De la misma manera, podemos obtener los valores utilizando los valores del método.
#
#       DICT.keys()=["Back in Black", "El lado oscuro de la luna", "El Guardaespaldas", "Graduación", "Thriller"
#
#       DICT.values() =[“1982”, “1980”, “1973”, “1992”, “1977”, “1976”, “1977”, “1977”]
